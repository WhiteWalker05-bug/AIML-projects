# %%
def square(number:int)->int:#the data type after the arrow indicates the type of output we can get
  return number*number
square(3)
# Out:
# 9

# %%
def print_id(user_id : int|str): #we use '|' for showing more than one data type in the function parameter
  print(user_id)
print('AW1244323')
# Out:
# AW1244323

# %%
numbers:list[int]=[10,20,30]
student_marks:dict[str,int]={'alice':90}
point :tuple [int,int]=(10,20)

# %%
def double(number:int)->int:
  return number *2
double('hi')
# Out:
# 'hihi'

# %% [markdown]
# type hints are just for reading and better documentation, they don't affect the outcome of the error

# %%
def calculate_average(marks:list[int])->float:
  return sum(marks)/len (marks)
def display_student(name:str,marks:list[int])->None:
  average:float=calculate_average(marks)
  print(f"student:{name}")
  print(f"average :{average:.2f}")
display_student('sakshi',[85,90,92])
# Out:
# student:sakshi
# average :89.00

# %%
class student:
  pass

student1=student()
student.marks=98
student.name="sakshi"
student.age=24
print(student.name)
# Out:
# sakshi

# %%
class student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
student1=student('sakshi',24)
print(student1.name)
# Out:
# sakshi

# %%
class student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def introduce(self):
      print(f"my name is {self.name}")
      print(f"age is {self.age}")

student=student('sakshi',20)
student.introduce()
# Out:
# my name is sakshi
# age is20

# %% [markdown]
# object.attribute

# %%
class BankAccount:
  def __init__(self,owner,balance):
    self.owner=owner
    self.balance=balance
  def deposit(self,amount):
    self.balance+=amount
  def withdraw(self,amount):
    if amount<=self.balance:
      self.balance-=amount
    else:
      print("insufficient balance")
  def show_balance(self):
    print(f"balance {self.balance}")
account=BankAccount('sakshi',5000)
account.deposit(1500)
account.withdraw(2000)
account.show_balance()
# Out:
# balance 4500

# %% [markdown]
# readme.md of this cell

# %%
class student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
         return f'{self.name},{self.age}'
    def intro(self,name):
        return f'My name is {self.name}'
student1=student('atharva',20)
print(student1)
# Out:
# atharva,20

# %%
class student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __repr__(self):
        return f'student({self.name},{self.age})'

student1=student('atharva',20)
print(repr(student1))
# Out:
# student(atharva,20)
