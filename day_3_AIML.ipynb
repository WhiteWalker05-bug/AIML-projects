# %% [markdown]
# <a href="https://colab.research.google.com/github/WhiteWalker05-bug/AIML-projects/blob/main/day_3_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=0
if a<5:
  print("hello world")
  a=a+1

# %%
span=0
while span<5:
  print("hellow world")
  span=span+1
# Out:
# hellow world
# hellow world
# hellow world
# hellow world
# hellow world

# %%
name=''
while name!='your name':
  print('please type our name')
  name=input('>')
print('thank you!')
# Out:
# please type our name
# >adi
# please type our name
# >your name
# thank you!

# %%
while True:
  print("type your name: ")
  name=input('>')
  if name=="your name":
    break
  print("thank you")
# Out:
# type your name:
# >adi
# thank you
# type your name:
# >your name

# %%
for num in range(10):
  if num%2==0:
    continue
  print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(5):
  print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
#range(stop)
for i in range(2,4):
  print("let's test range function")
# Out:
# let's test range function
# let's test range function

# %%
for i in range(0,15,5):
  print(i)
# Out:
# 0
# 5
# 10

# %%
total=0
for i in range(101):
  total=total+i
print(total)
# Out:
# 5050

# %%
import random
random.randint(1,10)
# Out:
# 4

# %% [markdown]
# module_name.function()

# %%
import sys

while True:
  print("type to exit")
  response=input('>')
  if response=="exit":
    print('you typed+',response)
# Out:
# type to exit
# >exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# This is a guess the number game.
import random
secret_number = random.randint(1, 20)
print('I am thinking of a number between 1 and 20.')

# Ask the player to guess 6 times.
for guesses_taken in range(1, 7):
    print('Take a guess.')
    guess = int(input('>'))
    if guess < secret_number:
        print('Your guess is too low.')
    elif guess > secret_number:
        print('Your guess is too high.')
    else:
        break # This condition is the correct guess!

if guess==secret_number:
  print("good job you guessed it in "+str(guesses_taken)+" guesses")
else:
  print("nope the number was"+str(secret_number)+"")
# Out:
# I am thinking of a number between 1 and 20.
# Take a guess.
