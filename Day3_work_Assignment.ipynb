# %% [markdown]
# <a href="https://colab.research.google.com/github/WhiteWalker05-bug/AIML-projects/blob/main/Day3_work_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  print("hello")
  print("hello")
  print("hello")

hello()
hello()
print("one more time")
hello()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# one more time
# hello
# hello
# hello

# %%
def divide(a,b):

  div_operator = input("Enter the desired operator for division (/, %, or //): ")
  if div_operator == "/":
    return a/b
  elif div_operator == "%":
      return a%b
  elif div_operator=='//':
    return a//b
  else:
    print("wrong operator chosen")

a=int(input("Enter the desired number: "))
b=int(input("Enter the desired number: "))

print(divide(a,b))
# Out:
# Enter the desired number: 1
# Enter the desired number: 4
# Enter the desired operator for division (/, %, or //): /
# 0.25

# %%
def add(a,b):
  return a+b

a=int(input("Enter the desired number:"))
b=int(input("Enter the desired number"))

print(add(a,b))
# Out:
# enter the desired number:23
# Enter the desired number12
# 35

# %%
def add(a,b):
  return a+b
result=add(2,3)
print(result)
# Out:
# 5

# %%
import random

def get_answer(n):
  if n==1:
    return "it is certain"
  elif n==2:
    return "ask again later"

r=random.randint(1,3)
print(get_answer(r))
# Out:
# it is certain

# %%
spam=None
print(spam)
# Out:
# None

# %%
def spam():
  eggs='hi'
print(spam(eggs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_774/3332042672.py in <cell line: 0>()
#       1 def spam():
#       2   eggs='hi'
# ----> 3 print(eggs)
#
# NameError: name 'eggs' is not defined

# %%
eggs="global"
def spam():
  eggs="local"
  print(eggs)
spam()
print(eggs)
# Out:
# local
# global

# %%
def divide(a,b):
  return a/b
a=int(input("Enter the first desired number: "))
b=int(input("Enter the second desired number: ") )

print(divide(a,b))
# Out:
# Enter the first desired number: 42
# Enter the second desired number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_774/2054514555.py in <cell line: 0>()
#       4 b=int(input("Enter the second desired number: ") )
#       5
# ----> 6 print(divide(a,b))
#
# /tmp/ipykernel_774/2054514555.py in divide(a, b)
#       1 def divide(a,b):
# ----> 2   return a/b
#       3 a=int(input("Enter the first desired number: "))
#       4 b=int(input("Enter the second desired number: ") )
#       5
#
# ZeroDivisionError: division by zero

# %%
def divide(n):
  return 42/n
print(divide(2))
# Out:
# 21.0

# %%
def spam(divided_by):
  try:
    return 42/divided_by
  except ZeroDivisionError:
    print("Error: Invalid argument.")
print(spam(2))
print(spam(12))
print(spam(0))
print(spam(3))
# Out:
# 21.0
# 3.5
# Error: Invalid argument.
# None
# 14.0

# %%
#this is animation program
import time, sys
indent = 0 # How many spaces to indent
indent_increasing = True # Whether the indentation is increasing or not
try:
    while True: # The main program loop
        print(' ' * indent, end='')
        print('********')
        time.sleep(0.1) # Pause for 1/10th of a second.
        if indent_increasing:
            # Increase the number of spaces:
            indent = indent + 1
    if indent == 20:
        # Change direction:
        indent_increasing = False
    else:
        # Decrease the number of spaces:
        indent = indent - 1
    if indent == 0:
        # Change direction:
        indent_increasing = True
except KeyboardInterrupt:
    sys.exit()
# Out:
# ********
#  ********
#   ********
#    ********
#     ********
#      ********
#       ********
#        ********
#         ********
#          ********
#           ********
#            ********
#             ********
#              ********
#               ********
#                ********
#                 ********
#                  ********
#                   ********
#                    ********
#                     ********
#                      ********
#                       ********
#                        ********
#                         ********
#                          ********
#                           ********
#                            ********
#                             ********
#                              ********
#                               ********
#                                ********
#                                 ********
#                                  ********
#                                   ********
# ...

# %%
#ValueError example

def cube():
    try:
          a=int(input("Enter the desired number: "))
          return a**3
    except ValueError:
            print("Error: enter integer please ")



print(cube())
# Out:
# Enter the desired number: hey
# Error: enter integer please
# None

# %%
#Type error example

def subtract():
  try :
    a=int(input("Enter the number of your desire: "))
    b=str(input("Enter the string of your type: "))

    return a-b

  except TypeError:
    print("change the input type")
    b=int(input("Enter the number of your desire: "))
    print("there you gooooo")
    return a-b


subtract()
# Out:
# Enter the number of your desire: 23
# Enter the string of your type: hey
# change the input type
# Enter the number of your desire: 24
# there you gooooo
# -1

# %%
#index error example
try:
  list=["A",'B',"C","D","H"]
  print(list[5])
except IndexError:
  print("this index does not exist, enter the existing ones")
# Out:
# this index does not exist, enter the existing ones

# %% [markdown]
# exception handling is finding a way to let the code run or stop it from showing a error
